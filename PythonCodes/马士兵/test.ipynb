# %%
import pandas as pd
df=pd.read_json('data.json',lines=True)
df['招标人'] = df['详情'].str.extract(r"(采购人名称：.*?\n|招标人名称：.*?\n)")
df[df['招标人'].notna()]=df[df['招标人'].notna()].applymap(lambda x: x[6:-1])
df
# Out:
#                            title  \
# 0         司2022年7月-2025年7月打包带采购项
# 1                     能建商城工程用纸采购
# 2                        鲁电厂项目部钢
# 3   09北京设备公司21045-GC工程事业部控制柜、仪表采
# 4   09北京设备公司21045-GC工程事业部控制柜、仪表采
# 5        设公司混凝土工程处肇明7#预制梁场门式起重机采
# 6                       沙坪项目部钢筋采
# 7          光伏项目照明灯具及配电箱采购2022060
# 8                 1000兆瓦调峰煤电项目部钢
# 9                    能建商城汽车衡采购项目
# 10                  能建商城工业胶片采购项目
# 11             武阳路面一标、二标项目电子汽车衡采
# 12                     项目桥面防水材料采
# 13                  22年悬臂双丝埋弧焊机采
# 14                    哇丽项目中低压阀门采
# 15     古能源有限公司长滩电厂2×66万千瓦机组工程化学水
# 16                        合金变形缝采
# 17                   河南濮阳项目耐磨弯头采
# 18             司巴基斯坦Mohmand项目钢材采
# 19                能建商城广东区域砂浆采购项目
#
#                                                    详情  \
# 0   葛洲坝集团易普力股份有限公司，就“易普力力能公司2022年7月-2025年7月打包带采购项目...
# 1   能建商城工程用纸采购采购中标结果公示\n（招标编号：DZSW-HW-01-DZSWCGZB-...
# 2   建建筑集团有限公司，就土耳其胡努特鲁电厂项目部钢材项目通过邀请招标方式进行采购，按规定程序进...
# ...
